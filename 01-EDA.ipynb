# %% [markdown]
# # My Data
# Link: https://www.kaggle.com/johnsmith88/heart-disease-dataset

# %% [markdown]
# # Variables
# 1. age
#     - age of patient
# 2. sex
#     - (1 = male, 0 = female)
# 3. cp
#     - chest pain type (4 values)
#     - 0: asymptomatic
#     - 1: atypical angina
#     - 2: non-anginal pain
#     - 3: typical angina
# 4. trestbs: resting blood pressure
# 5. chol: serum cholestoral in mg/dl
# 6. fbs: fasting blood sugar > 120 mg/dl
# 7. restecg: resting electrocardiographic results
#     - (values 0,1,2)
# 8. thalach: maximum heart rate achieved
# 9. exang: exercise induced angina
# 10. oldpeak: oldpeak = ST depression induced by exercise relative to rest
# 11. slope: the slope of the peak exercise ST segment
# 12. ca: number of major vessels colored by flourosopy
#     - (0-3) colored by flourosopy
# 13. thal:
#     - 3 = normal;
#     - 6 = fixed defect;
#     - 7 = reversable defect
# 14. target
#     - 0 = no heart disease
#     - 1 = heart disease)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
data = pd.read_csv('data/heart.csv')

# %%
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %% [markdown]
# # Cleaning the Data for clear EDA
# The data seems to be in good shape for modeling, however it could be a little confusing for EDA.
# We will rename column names and variables for clarity when performing EDA

# %%
data.columns.tolist()
# Out:
# ['age',
#  'sex',
#  'cp',
#  'trestbps',
#  'chol',
#  'fbs',
#  'restecg',
#  'thalach',
#  'exang',
#  'oldpeak',
#  'slope',
#  'ca',
#  'thal',
#  'target']

# %% [markdown]
# ### Renaming column names for clarity

# %%
data = data.rename(columns ={'age' : 'Age',
                             'sex' : 'Sex', 
                             'cp' : 'Chest Pain Type',
                             'trestbps' : 'Resting Blood Pressure',
                             'chol' : 'Cholesterol Level',
                             'fbs' : 'Fasting Blood Sugar',
                             'restecg' : 'Resting ECG Results',
                             'thalach' : 'Max Heart Rate Achieved',
                             'exang' : 'Exercise Induced Angina',
                             'oldpeak' : 'Old Peak',
                             'slope' : 'Slope',
                             'ca' : 'CA',
                             'thal' : 'Thalassemia',
                             'target' : 'Heart Disease'
                            })

# %%
data.head()
# Out:
#    Age  Sex  Chest Pain Type  Resting Blood Pressure  Cholesterol Level  \
# 0   52    1                0                     125                212
# 1   53    1                0                     140                203
# 2   70    1                0                     145                174
# 3   61    1                0                     148                203
# 4   62    0                0                     138                294
#
#    Fasting Blood Sugar  Resting ECG Results  Max Heart Rate Achieved  \
# 0                    0                    1                      168
# 1                    1                    0                      155
# 2                    0                    1                      125
# 3                    0                    1                      161
# 4                    1                    1                      106
#
#    Exercise Induced Angina  Old Peak  Slope  CA  Thalassemia  Heart Disease
# 0                        0       1.0      2   2            3              0
# 1                        1       3.1      0   0            3              0
# 2                        1       2.6      0   0            3              0
# 3                        0       0.0      2   1            3              0
# 4                        0       1.9      1   3            2              0

# %%
data.dtypes
# Out:
# Age                          int64
# Sex                          int64
# Chest Pain Type              int64
# Resting Blood Pressure       int64
# Cholesterol Level            int64
# Fasting Blood Sugar          int64
# Resting ECG Results          int64
# Max Heart Rate Achieved      int64
# Exercise Induced Angina      int64
# Old Peak                   float64
# Slope                        int64
# CA                           int64
# Thalassemia                  int64
# Heart Disease                int64
# dtype: object

# %%
data.shape
# Out:
# (1025, 14)

# %%
sns.set(font_scale=1.7)
plt.figure(figsize = (25, 10))
sns.heatmap(data.corr(), annot=True, fmt = '.1f', annot_kws={'size':22})
plt.show()

# %%
# pip install plotly

# %%
# pip install cufflinks

# %%
# pip install chart-studio

# %%
# can't get this to work, but would make a badass graph if it did 

import chart_studio.plotly as py
import plotly.graph_objs as go
from plotly.offline import iplot, init_notebook_mode
# Using plotly + cufflinks in offline mode
import cufflinks
cufflinks.go_offline(connected=True)
init_notebook_mode(connected=True)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-39-ff4d9d486e6c> in <module>
#       5 from plotly.offline import iplot, init_notebook_mode
#       6 # Using plotly + cufflinks in offline mode
# ----> 7 import cufflinks
#       8 cufflinks.go_offline(connected=True)
#       9 init_notebook_mode(connected=True)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\cufflinks\__init__.py in <module>
#      13 from . import datagen
#      14 from . import helper
# ---> 15 from . import tools
#      16 from . import colors
#      17 from . import pandastools
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\cufflinks\tools.py in <module>
#       4 import pandas as pd
#       5 import plotly.offline as py_offline
# ----> 6 import plotly.plotly as py
#       7 from plotly.graph_objs import Figure, Scatter, Line
#       8 from plotly.tools import make_subplots
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\plotly\plotly\__init__.py in <module>
#       2 from _plotly_future_ import _chart_studio_error
#       3
# ----> 4 _chart_studio_error("plotly")
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\_plotly_future_\__init__.py in _chart_studio_error(submodule)
#      47 chart_studio.{submodule} module instead.
#      48 """.format(
# ---> 49             submodule=submodule
#      50         )
#      51     )
#
# ImportError:
# The plotly.plotly module is deprecated,
# please install the chart-studio package and use the
# chart_studio.plotly module instead.

# %% [markdown]
# # EDA

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data.plot.scatter(x = 'age', y = 'chol')

# %%
data.plot.scatter(x = 'age', y = 'target')

# %%
data.sex.value_counts().plot.bar();
plt.xlabel('Gender');
plt.ylabel('')
plt.title('Males vs Females')
# Out:
# Text(0.5, 1.0, 'Males vs Females')

# %% [markdown]
# **We have way more males than females**

# %%
data.groupby('sex').target.value_counts().plot.bar()

# %%
data.age.hist(bins = 15, grid = False);
plt.xlabel('Age')
plt.ylabel('')
plt.title('Distribution of Age')
# Out:
# Text(0.5, 1.0, 'Distribution of Age')

# %% [markdown]
# **We have a unimodal, slightly skewed to the left dsitrubtion o age**
# **Most people in our data set are on the slightly older side**

# %%
data.groupby('sex').target.value_counts().plot.bar()

# %%
import seaborn as sns

# %%
data.groupby('sex').chest_pain_type.value_counts().plot.bar()

# %%
bg_color = (0.25, 0.25, 0.25)
sns.set(rc={"font.style":"normal",
            "axes.facecolor":bg_color,
            "figure.facecolor":bg_color,
            "text.color":"white",
            "xtick.color":"white",
            "ytick.color":"white",
            "axes.labelcolor":"white",
            "axes.grid":False,
            'axes.labelsize':25,
            'figure.figsize':(10.0,5.0),
            'xtick.labelsize':15,
            'ytick.labelsize':15})

# %%
ax = sns.regplot(x='resting_bp', y='chol',data=data, color="g")

# %%
data.groupby('sex').target.value_counts()
# Out:
# sex  target
# 0    1         226
#      0          86
# 1    0         413
#      1         300
# Name: target, dtype: int64
